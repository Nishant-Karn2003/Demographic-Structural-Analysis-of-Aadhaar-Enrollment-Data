# %%
import pandas as pd

df = pd.read_csv("C:/Users/nkarn/Desktop/UIDAI_Hackathon/data/Final_Clean_Data.csv")

# %%
print(df.shape)

print(df.columns)

print(df.head())
# Out:
# (772, 12)
# Index(['state', 'district', 'Sum of total_enrolled', 'Sum of age_0_5',
#        'Sum of age_5_17', 'Sum of age_18_greater', 'Sum of child_ratio',
#        'Sum of youth_ratio', 'Sum of adult_ratio', 'Sum of dependency_ratio',
#        'Sum of ESI', 'InfiniteDependency'],
#       dtype='object')
#                        state                  district  Sum of total_enrolled  \
# 0  Andaman & Nicobar Islands                  Andamans                     73
# 1  Andaman & Nicobar Islands                   Nicobar                     75
# 2  Andaman & Nicobar Islands  North And Middle Andaman                    129
# 3  Andaman & Nicobar Islands             South Andaman                    224
# 4             Andhra Pradesh     Alluri Sitharama Raju                   1214
#
#    Sum of age_0_5  Sum of age_5_17  Sum of age_18_greater  Sum of child_ratio  \
# 0              68                5                      0            0.931507
# ...

# %%
print("Unique States:", df["state"].nunique())

print("Unique Districts:", df["district"].nunique())

print("Infinite Dependency Districts:",
      df["InfiniteDependency"].sum())
# Out:
# Unique States: 36
# Unique Districts: 766
# Infinite Dependency Districts: 32

# %% [markdown]
# # LOADING DATA INTO SQL

# %%
from sqlalchemy import create_engine
import pymysql

# %%
engine = create_engine("mysql+pymysql://root:PASSWORD%40629@localhost/uidai_clean")

# %%
df.to_sql(
    name="uidai_district_enrollment_profile_clean",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 772
